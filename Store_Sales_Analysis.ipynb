# %% [markdown]
# # Store Sales Analysis

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset

# %%
SalesData = pd.DataFrame({'Product_Name' : ['Product_A','Product_B','Product_C','Product_A','Product_D','Product_B','Product_C','Product_E','Product_A','Product_D','Product_F','Product_C','Product_B','Product_E','Product_G','Product_A','Product_H','Product_F','Product_D','Product_E','Product_B','Product_H','Product_G','Product_A','Product_C','Product_D','Product_F','Product_E','Product_H','Product_G'],
                          'Price' : np.array([25,15,45,25,20,15,45,30,25,20,50,45,15,30,55,25,40,50,20,30,15,40,55,25,45,20,50,30,40,55]),
                          'Sales_Quantity' : np.array([50,30,40,60,55,35,25,20,45,65,15,35,70,30,10,50,20,25,75,40,60,35,15,55,20,85,30,50,25,12]),
                          'Sale_Date' : np.array(['2024-10-01','2024-10-01','2024-10-02','2024-10-02','2024-10-03','2024-10-03','2024-10-04','2024-10-04','2024-10-05','2024-10-05','2024-10-06','2024-10-06','2024-10-07','2024-10-07','2024-10-08','2024-10-08','2024-10-09','2024-10-09','2024-10-10','2024-10-10','2024-10-11','2024-10-11','2024-10-12','2024-10-12','2024-10-13','2024-10-13','2024-10-14','2024-10-14','2024-10-15','2024-10-15'])},
                          columns = ['Product_Name','Price','Sales_Quantity','Sale_Date'])

# %% [markdown]
# ## Analysis

# %%
SalesData
# Out:
#    Product_Name  Price  Sales_Quantity   Sale_Date
# 0     Product_A     25              50  2024-10-01
# 1     Product_B     15              30  2024-10-01
# 2     Product_C     45              40  2024-10-02
# 3     Product_A     25              60  2024-10-02
# 4     Product_D     20              55  2024-10-03
# 5     Product_B     15              35  2024-10-03
# 6     Product_C     45              25  2024-10-04
# 7     Product_E     30              20  2024-10-04
# 8     Product_A     25              45  2024-10-05
# 9     Product_D     20              65  2024-10-05
# 10    Product_F     50              15  2024-10-06
# 11    Product_C     45              35  2024-10-06
# 12    Product_B     15              70  2024-10-07
# 13    Product_E     30              30  2024-10-07
# 14    Product_G     55              10  2024-10-08
# 15    Product_A     25              50  2024-10-08
# 16    Product_H     40              20  2024-10-09
# ...

# %%
SalesData['Revenue'] = SalesData['Price'] * SalesData['Sales_Quantity']

# %%
SalesData
# Out:
#    Product_Name  Price  Sales_Quantity   Sale_Date  Revenue
# 0     Product_A     25              50  2024-10-01     1250
# 1     Product_B     15              30  2024-10-01      450
# 2     Product_C     45              40  2024-10-02     1800
# 3     Product_A     25              60  2024-10-02     1500
# 4     Product_D     20              55  2024-10-03     1100
# 5     Product_B     15              35  2024-10-03      525
# 6     Product_C     45              25  2024-10-04     1125
# 7     Product_E     30              20  2024-10-04      600
# 8     Product_A     25              45  2024-10-05     1125
# 9     Product_D     20              65  2024-10-05     1300
# 10    Product_F     50              15  2024-10-06      750
# 11    Product_C     45              35  2024-10-06     1575
# 12    Product_B     15              70  2024-10-07     1050
# 13    Product_E     30              30  2024-10-07      900
# 14    Product_G     55              10  2024-10-08      550
# ...

# %%
Sales_Data_Product_Groups = SalesData.groupby('Product_Name')['Revenue'].sum()

# %%
Sales_Data_Product_Groups
# Out:
# Product_Name
# Product_A    6500
# Product_B    2925
# Product_C    5400
# Product_D    5600
# Product_E    4200
# Product_F    3500
# Product_G    2035
# Product_H    3200
# Name: Revenue, dtype: int32

# %%
Total_Revenue = Sales_Data_Product_Groups.sum()

# %%
Total_Revenue
# Out:
# 33360

# %%
Sales_Data_Date_Groups = SalesData.pivot_table('Revenue', index ='Product_Name', columns = 'Sale_Date', fill_value=0)

# %%
Sales_Data_Date_Groups
# Out:
# Sale_Date     2024-10-01  2024-10-02  2024-10-03  2024-10-04  2024-10-05  \
# Product_Name
# Product_A           1250        1500           0           0        1125
# Product_B            450           0         525           0           0
# Product_C              0        1800           0        1125           0
# Product_D              0           0        1100           0        1300
# Product_E              0           0           0         600           0
# Product_F              0           0           0           0           0
# Product_G              0           0           0           0           0
# Product_H              0           0           0           0           0
#
# Sale_Date     2024-10-06  2024-10-07  2024-10-08  2024-10-09  2024-10-10  \
# Product_Name
# Product_A              0           0        1250           0           0
# Product_B              0        1050           0           0           0
# ...

# %%
SalesData
# Out:
#    Product_Name  Price  Sales_Quantity   Sale_Date  Revenue
# 0     Product_A     25              50  2024-10-01     1250
# 1     Product_B     15              30  2024-10-01      450
# 2     Product_C     45              40  2024-10-02     1800
# 3     Product_A     25              60  2024-10-02     1500
# 4     Product_D     20              55  2024-10-03     1100
# 5     Product_B     15              35  2024-10-03      525
# 6     Product_C     45              25  2024-10-04     1125
# 7     Product_E     30              20  2024-10-04      600
# 8     Product_A     25              45  2024-10-05     1125
# 9     Product_D     20              65  2024-10-05     1300
# 10    Product_F     50              15  2024-10-06      750
# 11    Product_C     45              35  2024-10-06     1575
# 12    Product_B     15              70  2024-10-07     1050
# 13    Product_E     30              30  2024-10-07      900
# 14    Product_G     55              10  2024-10-08      550
# ...

# %%
average_revenue = SalesData.groupby('Product_Name')['Revenue'].mean()

# %%
average_revenue
# Out:
# Product_Name
# Product_A    1300.000000
# Product_B     731.250000
# Product_C    1350.000000
# Product_D    1400.000000
# Product_E    1050.000000
# Product_F    1166.666667
# Product_G     678.333333
# Product_H    1066.666667
# Name: Revenue, dtype: float64

# %%
product_quantity = SalesData.groupby('Product_Name')['Sales_Quantity'].sum()

# %%
product_quantity
# Out:
# Product_Name
# Product_A    260
# Product_B    195
# Product_C    120
# Product_D    280
# Product_E    140
# Product_F     70
# Product_G     37
# Product_H     80
# Name: Sales_Quantity, dtype: int32

# %%
average_revenue_df = average_revenue.reset_index()
product_quantity_df = product_quantity.reset_index()

# %%
sales_analysis = pd.merge(average_revenue_df,product_quantity_df, on='Product_Name')

# %%
sales_analysis
# Out:
#   Product_Name      Revenue  Sales_Quantity
# 0    Product_A  1300.000000             260
# 1    Product_B   731.250000             195
# 2    Product_C  1350.000000             120
# 3    Product_D  1400.000000             280
# 4    Product_E  1050.000000             140
# 5    Product_F  1166.666667              70
# 6    Product_G   678.333333              37
# 7    Product_H  1066.666667              80

# %%
sales_analysis['Revenue_Per_Quantity'] = sales_analysis['Revenue'] / sales_analysis['Sales_Quantity']

# %%
sales_analysis
# Out:
#   Product_Name      Revenue  Sales_Quantity  Revenue_Per_Quantity
# 0    Product_A  1300.000000             260              5.000000
# 1    Product_B   731.250000             195              3.750000
# 2    Product_C  1350.000000             120             11.250000
# 3    Product_D  1400.000000             280              5.000000
# 4    Product_E  1050.000000             140              7.500000
# 5    Product_F  1166.666667              70             16.666667
# 6    Product_G   678.333333              37             18.333333
# 7    Product_H  1066.666667              80             13.333333

# %%
max_revenue_per_quantity = sales_analysis.loc[sales_analysis['Revenue_Per_Quantity'].idxmax()]

# %%
max_revenue_per_quantity
# Out:
# Product_Name             Product_G
# Revenue                 678.333333
# Sales_Quantity                  37
# Revenue_Per_Quantity     18.333333
# Name: 6, dtype: object

# %%
print(sales_analysis[['Product_Name', 'Revenue_Per_Quantity']])
# Out:
#   Product_Name  Revenue_Per_Quantity
# 0    Product_A              5.000000
# 1    Product_B              3.750000
# 2    Product_C             11.250000
# 3    Product_D              5.000000
# 4    Product_E              7.500000
# 5    Product_F             16.666667
# 6    Product_G             18.333333
# 7    Product_H             13.333333

# %%
min_revenue_per_quantity = sales_analysis.loc[sales_analysis['Revenue_Per_Quantity'].idxmin()]

# %%
min_revenue_per_quantity
# Out:
# Product_Name            Product_B
# Revenue                    731.25
# Sales_Quantity                195
# Revenue_Per_Quantity         3.75
# Name: 1, dtype: object

# %%
average_ratio = sales_analysis['Revenue_Per_Quantity'].mean()

# %%
average_ratio
# Out:
# 10.104166666666668

# %%
closest_to_average = sales_analysis.iloc[(sales_analysis['Revenue_Per_Quantity'] - average_ratio).abs().idxmin()]

# %%
closest_to_average
# Out:
# Product_Name            Product_C
# Revenue                    1350.0
# Sales_Quantity                120
# Revenue_Per_Quantity        11.25
# Name: 2, dtype: object

# %%
print(average_ratio)
# Out:
# 10.104166666666668

# %%
print(sales_analysis[['Product_Name', 'Revenue_Per_Quantity']])
# Out:
#   Product_Name  Revenue_Per_Quantity
# 0    Product_A              5.000000
# 1    Product_B              3.750000
# 2    Product_C             11.250000
# 3    Product_D              5.000000
# 4    Product_E              7.500000
# 5    Product_F             16.666667
# 6    Product_G             18.333333
# 7    Product_H             13.333333

# %%
closest_to_average = sales_analysis.iloc[(sales_analysis['Revenue_Per_Quantity'] - average_ratio).abs().idxmin()]
print(closest_to_average)
# Out:
# Product_Name            Product_C
# Revenue                    1350.0
# Sales_Quantity                120
# Revenue_Per_Quantity        11.25
# Name: 2, dtype: object

# %%
Total_Revenue
# Out:
# 33360

# %%
most_sold_product = product_quantity.idxmax()
most_sold_quantity = product_quantity.max()

# %%
print(product_quantity_df)
# Out:
#   Product_Name  Sales_Quantity
# 0    Product_A             260
# 1    Product_B             195
# 2    Product_C             120
# 3    Product_D             280
# 4    Product_E             140
# 5    Product_F              70
# 6    Product_G              37
# 7    Product_H              80

# %%
most_sold_product
# Out:
# 'Product_D'

# %%
most_sold_quantity
# Out:
# 280

# %% [markdown]
# ## Basic Visualisation and Analysis of Results

# %%
Sales_Data_Product_Groups
# Out:
# Product_Name
# Product_A    6500
# Product_B    2925
# Product_C    5400
# Product_D    5600
# Product_E    4200
# Product_F    3500
# Product_G    2035
# Product_H    3200
# Name: Revenue, dtype: int32

# %%
plt.figure(figsize=(10, 6))
Sales_Data_Product_Groups.plot(kind='bar', color='skyblue')
plt.title('Total Revenue of Products')
plt.xlabel('Products')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.savefig('Total_Revenue_of_Products.png')
plt.show()

# %%
Total_Revenue
# Out:
# 33360

# %%
Sales_Data_Date_Groups
# Out:
# Sale_Date     2024-10-01  2024-10-02  2024-10-03  2024-10-04  2024-10-05  \
# Product_Name
# Product_A           1250        1500           0           0        1125
# Product_B            450           0         525           0           0
# Product_C              0        1800           0        1125           0
# Product_D              0           0        1100           0        1300
# Product_E              0           0           0         600           0
# Product_F              0           0           0           0           0
# Product_G              0           0           0           0           0
# Product_H              0           0           0           0           0
#
# Sale_Date     2024-10-06  2024-10-07  2024-10-08  2024-10-09  2024-10-10  \
# Product_Name
# Product_A              0           0        1250           0           0
# Product_B              0        1050           0           0           0
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(Sales_Data_Date_Groups, annot=True, fmt='.0f', cmap='coolwarm')
plt.title('Total Revenue Distribution of Products by Date')
plt.xlabel('Sale Dates')
plt.ylabel('Products')
plt.savefig('Total_Revenue_Distribution_of_Products_by_Date.png')
plt.show()

# %%
average_revenue
# Out:
# Product_Name
# Product_A    1300.000000
# Product_B     731.250000
# Product_C    1350.000000
# Product_D    1400.000000
# Product_E    1050.000000
# Product_F    1166.666667
# Product_G     678.333333
# Product_H    1066.666667
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(10, 6))
average_revenue.plot(kind='bar', color='lightgreen')
plt.title('Average Revenue of Products')
plt.xlabel('Products')
plt.ylabel('Average Revenue')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.savefig('Average_Revenue_of_Products.png')
plt.show()

# %%
sales_analysis
# Out:
#   Product_Name      Revenue  Sales_Quantity  Revenue_Per_Quantity
# 0    Product_A  1300.000000             260              5.000000
# 1    Product_B   731.250000             195              3.750000
# 2    Product_C  1350.000000             120             11.250000
# 3    Product_D  1400.000000             280              5.000000
# 4    Product_E  1050.000000             140              7.500000
# 5    Product_F  1166.666667              70             16.666667
# 6    Product_G   678.333333              37             18.333333
# 7    Product_H  1066.666667              80             13.333333

# %%
max_revenue_per_quantity
# Out:
# Product_Name             Product_G
# Revenue                 678.333333
# Sales_Quantity                  37
# Revenue_Per_Quantity     18.333333
# Name: 6, dtype: object

# %%
min_revenue_per_quantity
# Out:
# Product_Name            Product_B
# Revenue                    731.25
# Sales_Quantity                195
# Revenue_Per_Quantity         3.75
# Name: 1, dtype: object

# %%
closest_to_average
# Out:
# Product_Name            Product_C
# Revenue                    1350.0
# Sales_Quantity                120
# Revenue_Per_Quantity        11.25
# Name: 2, dtype: object

# %%
plt.figure(figsize=(10, 6))
sales_analysis['Revenue_Per_Quantity'].plot(kind='bar', color='coral')
plt.axhline(y=average_ratio, color='blue', linestyle='--', label='Average Income / Number')
plt.title('Amount of Products per Revenue')
plt.xlabel('Products')
plt.ylabel('Amount per Revenue')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend()
plt.savefig('Amount_of_Products_per_Revenue.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
product_quantity.plot(kind='bar', color='skyblue')
plt.title('Sales Quantities of Products')
plt.xlabel('Products')
plt.ylabel('Sales Quantity')
plt.xticks(rotation=45)

plt.axhline(y=most_sold_quantity, color='red', linestyle='--', label=f'En Çok Satılan Ürün: {most_sold_product} ({most_sold_quantity})')
plt.legend()
plt.grid(axis='y')
plt.savefig('Sales_Quantities_of_Products.png')
plt.show()

# %% [markdown]
# # Information Note Sales Data Analysis and Conclusions

# %% [markdown]
# 1. General Sales Analysis
# Total Income 33,360 $
# Most Sold Product: Product_D (280 pieces)
# Most Sold Product Quantity: 280 units (Product_D)
#
# 3. Revenue by Product
# Product Revenue:
# Product_A: 1,300 $
#
# Product_B: 731.25 $
#
# Product_C: 1,350 $
#
# Product_D: 1,400 $
#
# Product_E: 1,050 $
#
# Product_F: 1,166.67 $
#
# Product_G: 678.33 $
#
# Product_H: 1,066.67 $
#
# 4. Sales Quantities
# Total Sales Amounts:
# Product_A: 260
# Product_B: 195
# Product_C: 120
# Product_D: 280
# Product_E: 140
# Product_F: 70
# Product_G: 37
# Product_H: 80
#
# 6. Sales Amount per Revenue Analysis
# Sales Amount per Revenue:
#
#
# Product_G: 18.33 $ (highest)
#
# Product_B: 3.75 $ (lowest)
#
# 7. Analyses Supported by Graphs
# Sales Amounts of Products: Shown with a bar graph. The most sold product was highlighted as Product_D.
# Relationship between Revenue and Sales Amount: Analysing the amount of sales per revenue helped to identify which products were more profitable.

# %% [markdown]
# # Strategic Decision Recommendations

# %% [markdown]
# 1. Best-Selling Product and its Impact on Revenue:
#
# * The fact that Product_D is the best-selling product requires reviewing the marketing strategies and inventory management of this product.
#
# * Considering the high demand for the product, increasing the production quantity of Product_D and organising special campaigns for this product can further support revenue growth.
#
# 2. Revenue Analysis and Product Performance:
#
# * Analysis of product revenues shows that high revenue-generating products such as Product_D and Product_C stand out. By focusing on the promotion and development of these products, you can increase sales.
#
# * For low revenue-generating products such as Product_G and Product_B, it may be useful to re-evaluate marketing strategies and make changes to the pricing or features of these products.
#
# 3. Sales Amounts of Products:
#
# * Analysing total sales volumes shows which products are most in demand. However, some products (e.g. Product_F and Product_G) have low sales volumes. These products may need to be repositioned or different marketing strategies may need to be applied.
#
# * It may be recommended to develop new methods to reach potential customers by analysing the target audience, especially for products with low sales volumes.
#
# 4. Analysing Sales Amount per Revenue:
#
# * Product_G's high sales per revenue indicates the potential to increase the profitability of this product. Alternative methods could be explored to reduce production costs or provide more added value.
#
# * Product_B's low sales per revenue indicates the need for a price revision or improvement for this product. It may be useful to add innovations to the marketing campaigns of this product or to improve product features.
#
# 5. Analyses Supported by Graphs:
#
# * Visualisation is an effective tool to better understand product performance. Analyses supported by visuals, such as bar charts, can help the team make faster and more effective decisions.
#
# * Regularly updating these charts will enable to track the effectiveness of sales strategies and make changes quickly when necessary.

# %% [markdown]
# ## If the current sales trends continue in this way:

# %% [markdown]
# Increased Profit Margins:
#
# High sales volume and revenue can increase the company's profit margins. Continued sales of particularly profitable products can positively affect total profit.
#
# Difficulties in Inventory Management:
#
# The increase in demand for the best-selling products can lead to difficulties in inventory management. If stock levels are not managed correctly, there may be disruptions in the supply chain, which may result in lost sales.
#
# Increased Customer Loyalty:
#
# Providing consistently high quality products and responding quickly to customer demands can increase customer loyalty. This can expand the customer base in the long term.
#
# Expansion of Market Share:
#
# A good sales performance can lead to an increase in market share. The company can strengthen its position in the sector by increasing its competitive advantage.
#
# Opportunities for Innovative Product Development:
#
# Since sales data shows which products are more popular, this information can also be used in new product development processes. The characteristics of successful products and customer feedback can be taken into account in the design of new products.
#
# Financial Strengthening:
#
# Continued successful sales can strengthen a company's financial position. This can lead to opportunities to make investments, expand into new markets or expand existing infrastructure.
